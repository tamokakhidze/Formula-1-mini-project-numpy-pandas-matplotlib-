# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('drivers.csv') #ვკითხულობთ csv ფაილს სახელად drivers, მონაცემებს ვათავსებთ დატარეიმში სახელად df

# %%
df
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
# 854       856         de_vries     21  DEV      Nyck    de Vries  1995-02-06
# 855       857          piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858         sargeant      2  SAR     Logan    Sargeant  2000-12-31
#
# ...

# %%
df.head(10)
# Out:
#    driverId   driverRef number code   forename     surname         dob  \
# 0         1    hamilton     44  HAM      Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI       Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS       Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO   Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV     Heikki  Kovalainen  1981-10-19
# 5         6    nakajima     \N  NAK     Kazuki    Nakajima  1985-01-11
# 6         7    bourdais     \N  BOU  Sébastien    Bourdais  1979-02-28
# 7         8   raikkonen      7  RAI       Kimi   Räikkönen  1979-10-17
# 8         9      kubica     88  KUB     Robert      Kubica  1984-12-07
# 9        10       glock     \N  GLO       Timo       Glock  1982-03-18
#
#   nationality                                                url
# 0     British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# ...

# %%
df[['forename', 'surname']] #გამოგვაქვს კონკრეტული სვეტები
# Out:
#      forename     surname
# 0       Lewis    Hamilton
# 1        Nick    Heidfeld
# 2        Nico     Rosberg
# 3    Fernando      Alonso
# 4      Heikki  Kovalainen
# ..        ...         ...
# 852      Mick  Schumacher
# 853    Guanyu        Zhou
# 854      Nyck    de Vries
# 855     Oscar     Piastri
# 856     Logan    Sargeant
#
# [857 rows x 2 columns]

# %%
df.set_index('forename', inplace=True) #ვნიშნავთ ინდექსირებას forename სვეტის მიმართ

# %%
df
# Out:
#           driverId        driverRef number code     surname         dob  \
# forename
# Lewis            1         hamilton     44  HAM    Hamilton  1985-01-07
# Nick             2         heidfeld     \N  HEI    Heidfeld  1977-05-10
# Nico             3          rosberg      6  ROS     Rosberg  1985-06-27
# Fernando         4           alonso     14  ALO      Alonso  1981-07-29
# Heikki           5       kovalainen     \N  KOV  Kovalainen  1981-10-19
# ...            ...              ...    ...  ...         ...         ...
# Mick           854  mick_schumacher     47  MSC  Schumacher  1999-03-22
# Guanyu         855             zhou     24  ZHO        Zhou  1999-05-30
# Nyck           856         de_vries     21  DEV    de Vries  1995-02-06
# Oscar          857          piastri     81  PIA     Piastri  2001-04-06
# Logan          858         sargeant      2  SAR    Sargeant  2000-12-31
#
#          nationality                                             url
# forename
# ...

# %%
nationality_filter = df['nationality'] == 'German' #ვქმნით პირველ ფილტრს

# %%
birthday_filter = df['dob'] > '1985-06-27' #ვქმნით მეორე ფილტრს

# %%
filtr1 = df[nationality_filter & birthday_filter] #& ოპერატორით ჩვენს შექმნილ ორ ფილტრს ვაერთიანებთ

# %%
filtr1
# Out:
#            driverId        driverRef number code     surname         dob  \
# forename
# Sebastian        20           vettel      5  VET      Vettel  1987-07-03
# Nico            807       hulkenberg     27  HUL  Hülkenberg  1987-08-19
# Pascal          836         wehrlein     94  WEH    Wehrlein  1994-10-18
# Mick            854  mick_schumacher     47  MSC  Schumacher  1999-03-22
#
#           nationality                                                url
# forename
# Sebastian      German      http://en.wikipedia.org/wiki/Sebastian_Vettel
# Nico           German  http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg
# Pascal         German       http://en.wikipedia.org/wiki/Pascal_Wehrlein
# Mick           German       http://en.wikipedia.org/wiki/Mick_Schumacher

# %%
df.sort_values(by=['surname', 'dob']) #ვასორტირებთ ცხრილს ორი პარამეტრის გამოყენებით
# Out:
#           driverId   driverRef number code        surname         dob  \
# forename
# Carlo          446       abate     \N   \N          Abate  1932-07-10
# George         725   abecassis     \N   \N      Abecassis  1913-03-21
# Kenny          186     acheson     \N   \N        Acheson  1957-11-27
# Philippe       113       adams     \N   \N          Adams  1969-11-19
# Walt           796        ader     \N   \N           Ader  1913-12-15
# ...            ...         ...    ...  ...            ...         ...
# Syd            474       vyver     \N   \N  van der Vyver  1920-06-01
# Rikky          313        opel     \N   \N       von Opel  1947-10-14
# Hans           717  hans_stuck     \N   \N      von Stuck  1900-12-27
# Wolfgang       476       trips     \N   \N      von Trips  1928-05-04
# Philippe       741   etancelin     \N   \N      Étancelin  1896-12-28
#
#               nationality                                                url
# forename
# ...

# %%
meanForId = df['driverId'].mean() #meanForId ცვლადში ვათავსებთ driverId სვეტის მნიშვნელობების საშუალოს

# %%
meanForId
# Out:
# 429.0571761960327

# %%
stdd = df['driverId'].std()  #stdd ცვლადში ვათავსებთ driverId სვეტის მნიშვნელობების სტანდარტულ გადახრას

# %%
stdd
# Out:
# 247.63240156833837

# %%
minn = df['number'].min() #minn ცვლადში ვათავსებთ number სვეტის მნიშვნელობების მინიმალურ მნიშვნელობას

# %%
minn
# Out:
# '10'

# %%
maxx = df['driverId'].max() #minn ცვლადში ვათავსებთ driverId სვეტის მნიშვნელობების მინიმალურ მნიშვნელობას
maxx
# Out:
# 858

# %%
median = df['driverId'].median() 
median
# Out:
# 429.0

# %%
df['dob'] = pd.to_datetime(df['dob']) #dob სვეტი ვაქციოთ დეითთაიმ იბიექტად

# %%
count = df['dob'].dt.year.value_counts().sort_index() #date of birth სვეტიდან ვაექსტრაქტებთ year-ს, ვითვლით თითოეულის რაოდენობას და ვასორტირებთ

# %%
top_20_dob_counts = count.nlargest(20) #თავდაპირველად დიაგრამა ყველა მონაცემის მიხედვით ავაგე, მაგრამ იქედან გამომდინარე, რომ მონაცემების რაოდენობა რამ
#დენიმე ასეულია, უკეთესი ხილვადობისთვის 20 ყველაზე დიდ მონაცემზე დაყრდნობით ავაგე საბოლოოდ.

# %%
plt.figure(figsize=(12, 6)) #დიაგრამას ვანიჭებთ ზომას

# %%
top_20_dob_counts.plot(kind='bar') #ვაგებთ ბარს. kind-ში ვუთითებთ თუ რა ტიპის დიაგრამა გვინდა.
# Out:
# <Axes: xlabel='dob'>

# %%
plt.xlabel('Date of Birth (Year)')
plt.ylabel('Count')
plt.title('Top 20 Date of Birth Bar Chart')
# Out:
# Text(0.5, 1.0, 'Top 20 Date of Birth Bar Chart')

# %%
df['dob'] = pd.to_datetime(df['dob'])

# %%
df['year'] = df['dob'].dt.year

# %%
year_counts = df['year'].value_counts().sort_index()

# %%
plt.plot(year_counts.index, year_counts.values, marker='', linestyle='-', color='r')
